# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ###Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)

# %%
ABC=pd.read_csv("C:\\Users\\nikhi\\assignments\\myexcel - myexcel.csv")
ABC
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
h=np.random.randint(low=150,high=181,size=(458,1))

# %%
hdf=pd.DataFrame(h)
hdf
# Out:
#        0
# 0    166
# 1    177
# 2    166
# 3    161
# 4    163
# ..   ...
# 453  173
# 454  157
# 455  161
# 456  155
# 457  150
#
# [458 rows x 1 columns]

# %%
ABC['Height']=h
(ABC)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     163     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     173     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     155     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # Analysis Tasks:

# %% [markdown]
# # 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
employees_team=ABC['Team'].value_counts()
employees_team
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percentage_split=(employees_team/len(ABC))*100
print('Percentage split relative to the total number of employees')
percentage_split
# Out:
# Percentage split relative to the total number of employees
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# ...

# %%
plt.figure(figsize=(10,5))
employees_team.plot(kind='bar',color='r')
plt.title('Distribution of employees across teams')
plt.ylabel('Number of employees')
plt.show()

# %% [markdown]
# # insight: New Orleans Pelicans	holds most number of employees-15 out of 458, which is 4.148472% of the total employees.
# #         Minnesota Timberwolves have least number of employees-14, and it is 3.056769% of the total.

# %% [markdown]
# # 2. Segregate employees based on their positions within the company.

# %%
ABC
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     163     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     173     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     155     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
p=ABC['Position'].value_counts()
print('Dividing employees based on their positions within the company')
p
# Out:
# Dividing employees based on their positions within the company
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
p.plot(kind='bar',color='b')
plt.ylabel('Number of employees')
plt.title('Number of employees in each postions')
plt.show()

# %% [markdown]
# # insght: most number of employees is in position SG-102 and  least number of employees is in positon C-79

# %% [markdown]
# # 3. Identify the predominant age group among employees.

# %%
a=ABC['Age'].value_counts()
a
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
sns.countplot(x='Age',data=ABC)
plt.ylabel('count')
plt.title('Number of employees in different age groups')
plt.show()

# %% [markdown]
# # insight: the age group that comes most number of employees is 24 and minimus=m is 19

# %% [markdown]
# # 4. Discover which team and position have the highest salary expenditure

# %%
ABC
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     166     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     166     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     163     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     173     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     161     256
# 456    Jeff Withey       Utah Jazz      24        C   26     155     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
ABC[["Salary","Position","Team"]].max()
# Out:
# Salary              25000000.0
# Position                    SG
# Team        Washington Wizards
# dtype: object

# %%
sns.boxplot(y='Salary',data=ABC)
plt.show()

# %%
sns.histplot(x='Position',data=ABC,color="r")
plt.show()

# %% [markdown]
# # insight:  Washington Wizards has the highest salary expenditure and for the position SG

# %% [markdown]
# # 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
sns.barplot(x="Age",y="Salary",data=ABC)
plt.show()

# %% [markdown]
# # it is evident that age group between 24 to 34 has higher salary compared to others only excemption of age 37
